# %% [markdown]
# <a href="https://colab.research.google.com/github/Chunshan-Theta/SchoolMentor/blob/main/DataProcess/ClassBookToRaw.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests

resource: str = requests.get("https://raw.githubusercontent.com/Chunshan-Theta/SchoolMentor/main/DataProcess/ClassBook_7_1.txt").text

# %%
from typing import Callable, List
import re

cutLine: Callable = lambda x: [l for l in x.split("\n") if l != ""]
removeSpace: Callable = lambda x: [l.replace("\u3000","") for l in x]
removeAnnoatation: Callable = lambda x: [re.sub(r"\([^()][A-Za-z0-9_]*\)", '', l) for l in x]
combineString: Callable = lambda x: "".join(x)

def cutParagraph(s:str) -> List[str]:
  stop_symbol = "。"
  return_array: List[str] = []
  min_size = 50
  start_pointer = 0
  end_pointer = min_size+1
  while end_pointer < len(s):
    # print(f"{end_pointer}/{len(s)}")
    if s[end_pointer] == stop_symbol:
      return_array.append(s[start_pointer: end_pointer+1])
      start_pointer = end_pointer+1
      end_pointer += start_pointer+min_size
    end_pointer += 1
  return_array.append(s[start_pointer: end_pointer+1])
  return return_array



#
lines =  cutLine(resource)
lines = removeSpace(lines)
lines = removeAnnoatation(lines)
lines = combineString(lines)
lines = cutParagraph(lines)
lines
# Out:
# ['３CHAPTER生物體的營養１食物中的養分活動３１食物中澱粉與糖的測定３植物如何製造養分活動３３光合作用變因之探討２酵素活動３２酵素的作用４人體如何獲得養分妳看這棵樹長的好高大。',
#  '欸？這個吊飾是什麼？對阿，感覺可以照到很多陽光。這個嗎？這是我去年上生物課的時候做的，也可以做有字樣的喔！生活情境小劇場DailyLifeSituation５８有時間再教妳，我要回家了！掰掰。中間的藍色圖案是怎麼印上去的？好特別喔。用特殊染劑印上去的。教教我嘛，不然這個吊飾借我研究一下。',
#  '可以教我怎麼做嗎？時間不早了快走吧。植物葉片為了照到更多光，盡可能往上生長來增加照光面積，為什麼植物會需要光照？葉子吊飾上的藍色圖案是如何出現的？Q１Q２５９６０不同生物獲得與利用養分的方式不盡相同，但相同的是，養分可能是生物體內構造的成分，可能和調節生物體的代謝作用有關，也可能產生能量，以利生物體維持生命現象。養分與能量人們需要透過攝食而獲得生存所需的大部分養分，這些養分可分為六大類，包括可以產生能量的醣類（碳水化合物）、蛋白質和脂質，以及無法產生能量的水、礦物質和維生素（圖３１）。食物中養分在人體內產生能量的多寡，人們多以燃燒食物所產生的熱量作為推測依據。常用的熱量單位是「卡」或「大卡」，人體可分解獲得熱量的養分中，１公克的醣類或蛋白質可產生４大卡熱量，１公克的脂質則可產生９大卡熱量。',
#  '１人們透過食物所主要攝取的養分圖３１３１食物中的養分脂質水蛋白質維生素礦物質醣類可以產生能量無法產生能量第３章生物體的營養６１熱量的估算我們可藉由燃燒食物而加熱容器中的水，觀察水溫的變化，推測食物所含熱量的多寡。１公克的水上升１℃所需的熱量，即為１卡，而１０００卡熱量等於一大卡熱量。２１‧花生米燃燒完全之後，錐形瓶中的水溫，從攝氏幾度升高到幾度？瓶中的水共獲得多少熱量？２‧花生米中養分本身含有的熱量，是否會和錐形瓶中水所獲得的熱量相同？為什麼？３‧右圖為某市售鮮乳之營養標示，則此鮮乳在人體內最多能夠產生多少熱量呢？取一段鐵絲或廢棄的解剖針，一端固定於橡皮塞，一端刺入一顆花生。以２５０mL錐形瓶裝入５０mL（即５０g）的水，以溫度計測量並記錄水溫。將陶瓷纖維網放在三腳架上，再將錐形瓶放在陶瓷纖維網上。調整鐵絲上花生與陶瓷纖維網的距離（約２cm），並確認橡皮塞不會傾倒。點燃橡皮塞上的花生，迅速以剪好的鋁箔圍住三腳架，測量錐形瓶內水溫變化。※建議使用炒過的花生米，亦可使用洋芋片替代，較易成功燃燒。示範活動測量花生米的熱量步驟問題與討論５１２３４將花生固定於橡皮塞上備好水溫測量裝置並點燃花生等待至燃燒完全，觀測水溫變化花生溫度計鋁箔鐵絲６２食物中澱粉與糖的測定目的醣類包含很多種類，本活動在學習測定澱粉與糖的簡易方法，進一步測定食物中是否具有澱粉與糖。黃褐色的碘液，遇澱粉會變成藍黑色或紫紅色。淺藍色的本氏液，加入葡萄糖溶液（或麥芽糖溶液）後加熱，會依據糖分含量和作用時間，出現綠、黃、橙、紅等顏色變化。',
#  '一、二、步驟一、食物中澱粉的測定活動３１器材（以組為單位）在滴有水和澱粉液的凹槽中滴一滴碘液，觀察並記錄顏色的變化。在梅花盤中間凹槽滴一滴水，並任選外圍一個凹槽中滴一滴澱粉液。梅花盤X１滴管X３５００mL燒杯X１碘液適量澱粉液（５％）葡萄糖液（５％）水果適量本氏液適量酒精燈X１陶瓷纖維網X１試管X４試管架研缽及杵X１原理說明葡萄糖含量無高水澱粉液碘液三腳架X１１０mL量筒X１※若實驗室有本生燈，建議使用本生燈做為熱源。第３章生物體的營養６３將米飯與果肉磨成泥，分別放入試管C、D，各加入２mL本氏液，使溶液混合均勻。※亦可以紗布和水過濾食物殘渣取得濾液。在梅花盤外圍空的凹槽放入米飯與果肉（蘋果、橘子、香蕉、奇異果或葡萄等），並在裝有米飯與果肉的凹槽滴一滴碘液，觀察並記錄米飯與果肉的顏色變化。在試管A、B中分別加入２mL本氏液，輕輕搖動試管使溶液混合均勻後，再把試管放入步驟的燒杯中，觀察並記錄加熱前、後的顏色變化。重複步驟，加熱試管C、D，觀察並記錄加熱前、後的顏色變化。取兩支試管A、B，分別放入２mL水及葡萄糖液。１‧碘液滴入澱粉液變成藍黑色或紫紅色，表示碘液是與澱粉或是水發生作用？２‧在糖分的測定活動中，A試管的實驗意義為何？３‧你檢測的食物中，哪些食物含有「糖」呢？如何判斷？在５００mL燒杯中裝入約３００mL的溫水，放在陶瓷纖維網上加熱備用。米飯蘋果香蕉二、食物中糖分的測定５葡萄糖液米飯水蘋果泥問題與討論６４養分在生物體內經過不同的化學反應，可產生能量或其他物質，這些反應統稱為代謝作用。其中，能將大分子轉變成小分子的作用稱為分解作用，而將小分子結合成大分子的作用稱為合成作用（圖３２）。酵素的功能與特性酵素，又稱為?，能促進代謝反應的進行，在代謝反應過程中，和酵素結合而作用的物質，稱為受質。酵素和受質的結合具專一性，例如：人體唾液中的澱粉?能夠和澱粉結合，促進澱粉的分解，但因不能和纖維素結合，無法分解纖維素（圖３３）。一般而言，酵素反應的環境若未有溫度、酸鹼性或其他特殊條件的改變，酵素在反應結束後，仍可與新的受質作用。１３２酵素圖３２代謝作用的類型圖３３酵素具有專一性（以澱粉?為例）分解作用大分子轉變產生小分子合成作用小分子結合成
蛋白質脂質醣類、脂質、蛋白質４‧人體的消化系統：消化道與消化腺（１）消化道口咽食道胃小腸大腸肛門（２）消化腺第３章生物體的營養７７７８吃酵素，補酵素？酵素（?）是生物體代謝的催化劑，舉凡生物體內物質的分解、合成或是轉換作用，幾乎都需要酵素協助。酵素的種類包括消化酵素、合成酵素、新陳代謝酵素等，大部分人體酵素的功能無法由外界的物質所取代。當酵素不足或是功能異常時，可能就會造成病症，例如：黑色素細胞產生某些酵素RoaminginScience科學漫遊的功能異常，會影響黑色素的生成，甚至導致白化症；若消化道中的酵素功能異常，可能會導致某些蛋白質造成人體的過敏反應，而產生發炎。酵素在人體內的效果這麼的神奇，那麼，可藉由食用「酵素保健食品」來改善或治癒人體的病變嗎？第３章生物體的營養７９坊間聽見的「吃酵素補酵素」，其實是一知半解。市售酵素保健食品幾乎都是消化酵素，當人體消化功能不佳、攝取養分過多時，它們可以協助分解，減少人體的消化負擔，但無法取代人體所有酵素的功能，例如：具抗氧化能力的過氧化氫?、協助黑色素形成的酪胺酸?等，都需要細胞自行合成，無法經由外界的吸收而利用。就像古時候的迷思：吃（魚）眼補眼、吃（豬）腦補腦，這是不可能會發生的！況且，吃了高膽固醇的許多人會吃酵素保健食品來幫助人體消化。這是有可能的說法嗎？為什麼？這是有可能的。因為人體若是攝取酵素食品，在這些攝取的酵素未被人體自己產生的酵素分解之前，的確有機會幫助消化到的食物分解。但大多被攝取的酵素，多半會被人體消化道當成是養分分解，但即使如此也應適量攝取即可，過量對人體依然沒有益處。若有電視廣告宣稱吃了酵素食品，可以補充人體細胞內的酵素。這是正確的說法嗎？為什麼？大多酵素的主要成分是蛋白質，本身要進入細胞便不是太容易，並且，若是進入人體的消化道，很難不被消化分解而接近入小腸絨毛，所以，這個說法不太適當喔！AnsAns１２豬腦，可能還會導致或加速心血管疾病呢！酵素大部分是以蛋白質為基本結構，容易受溫度、酸鹼性等因素影響其功能。無論何種酵素食品，當它們進入人體消化道後，也如同其他蛋白質養分，被分解為胺基酸後，經小腸絨毛細胞吸收，再形成其他人體構造的原料，例如：肌肉、毛髮、指甲以及細胞內的各種酵素都是由蛋白質組成的。所以，別再以為「吃酵素，就能補酵素」，小心補到其他地方去喔！']

# %% [markdown]
# call api

# %%
from requests.models import Response
import requests
from typing import Dict, Any
test_text: str = "１人們透過食物所主要攝取的養分圖３１３１食物中的養分脂質水蛋白質維生素礦物質醣類可以產生能量無法產生能量第３章生物體的營養６１熱量的估算我們可藉由燃燒食物而加熱容器中的水，觀察水溫的變化，推測食物所含熱量的多寡。１公克的水上升１℃所需的熱量，即為１卡，而１０００卡熱量等於一大卡熱量。２１‧花生米燃燒完全之後，錐形瓶中的水溫，從攝氏幾度升高到幾度？瓶中的水共獲得多少熱量？２‧花生米中養分本身含有的熱量，是否會和錐形瓶中水所獲得的熱量相同？為什麼？３‧右圖為某市售鮮乳之營養標示，則此鮮乳在人體內最多能夠產生多少熱量呢？取一段鐵絲或廢棄的解剖針，一端固定於橡皮塞，一端刺入一顆花生。以２５０mL錐形瓶裝入５０mL（即５０g）的水，以溫度計測量並記錄水溫。將陶瓷纖維網放在三腳架上，再將錐形瓶放在陶瓷纖維網上。調整鐵絲上花生與陶瓷纖維網的距離（約２cm），並確認橡皮塞不會傾倒。點燃橡皮塞上的花生，迅速以剪好的鋁箔圍住三腳架，測量錐形瓶內水溫變化。※建議使用炒過的花生米，亦可使用洋芋片替代，較易成功燃燒。示範活動測量花生米的熱量步驟問題與討論５１２３４將花生固定於橡皮塞上備好水溫測量裝置並點燃花生等待至燃燒完全，觀測水溫變化花生溫度計鋁箔鐵絲６２食物中澱粉與糖的測定目的醣類包含很多種類，本活動在學習測定澱粉與糖的簡易方法，進一步測定食物中是否具有澱粉與糖。黃褐色的碘液，遇澱粉會變成藍黑色或紫紅色。淺藍色的本氏液，加入葡萄糖溶液（或麥芽糖溶液）後加熱，會依據糖分含量和作用時間，出現綠、黃、橙、紅等顏色變化。"

def callLLM_splitAricle(test_text: str) -> Response
  system_text: str = """
  透過分析一篇中文文章，包括將其分成段落，提取摘要，並將摘要轉換成關鍵字，請用中文回應
  1.拆分段落內容：
      請幫我把下面的中文文章分成幾個段落，每個段落都是一個完整的描述。

  2.提取摘要：
      請幫我從每個段落中提取一個簡短的摘要來總結其主要內容。

  3.轉化為5個關鍵字：
    將每個段落的摘要轉化為五個關鍵字，以便更容易理解核心訊息。

  這任務你必使用這個格式回應：
    第 1 段：[請在此插入第 1 段內容] => 摘要：[請在此插入第 1 段的摘要] => 關鍵字：[此處列出五個關鍵字，以逗號分隔]
    第 2 段：[請在此插入第 2 段內容] => 摘要：[請在此插入第 2 段的摘要] => 關鍵字：[此處列出五個關鍵字，以逗號分隔]
    ...（繼續這個模式）...
  """
  return requests.post("http://*************/callapi/chatGPT?temperature=0&max_tokens=2048&top_p=1&purpose=refactor-test",json=[{
    "role": "system",
    "content": system_text
    },
    {
    "role": "user",
    "content": test_text
  }])
r = callLLM_splitAricle(test_text)
r.text
# Out:
# '{"id":"chatcmpl-85kYmLBihvV8KCeJv6OBSNsV5Qb1o","object":"chat.completion","created":1696381308,"model":"gpt-35-turbo","choices":[{"index":0,"finish_reason":"stop","message":{"role":"assistant","content":"第 1 段：介紹食物所含的養分和能量，以及如何通過燃燒食物來估算其熱量。 => 摘要：食物的養分和能量，以及通過燃燒食物來估算其熱量。 => 關鍵字：食物，養分，能量，燃燒，熱量\\n第 2 段：介紹如何通過燃燒花生米來測量其熱量，並探討花生米中養分本身所含的熱量是否與燃燒後所產生的熱量相同。 => 摘要：通過燃燒花生米來測量其熱量，並探討養分本身所含的熱量是否與燃燒後所產生的熱量相同。 => 關鍵字：花生米，燃燒，熱量，養分，比較\\n第 3 段：介紹一種市售鮮乳的營養標示，並問題是該鮮乳在人體內最多能夠產生多少熱量。 => 摘要：介紹市售鮮乳的營養標示，並問題是該鮮乳在人體內最多能夠產生多少熱量。 => 關鍵字：鮮乳，營養標示，熱量，人體，問題\\n第 4 段：介紹測量食物中澱粉和糖的方法，包括使用碘液和本氏液。 => 摘要：介紹測量食物中澱粉和糖的方法，包括使用碘液和本氏液。 => 關鍵字：澱粉，糖，測量，碘液，本氏液\\n第 5 段：介紹測量花生米熱量的步驟，包括將花生固定在橡皮塞上，點燃花生，觀察水溫變化等。 => 摘要：介紹測量花生米熱量的步驟，包括將花生固定在橡皮塞上，點燃花生，觀察水溫變化等。 => 關鍵字：花生米，熱量，測量，步驟，觀察"}}],"usage":{"completion_tokens":775,"prompt_tokens":1481,"total_tokens":2256}}'

# %%
response = r.json()
print(response)
for unit in response["choices"][0]["message"]["content"].split("\n"):
  print(unit.split("=>"))
# Out:
# {'id': 'chatcmpl-85kYmLBihvV8KCeJv6OBSNsV5Qb1o', 'object': 'chat.completion', 'created': 1696381308, 'model': 'gpt-35-turbo', 'choices': [{'index': 0, 'finish_reason': 'stop', 'message': {'role': 'assistant', 'content': '第 1 段：介紹食物所含的養分和能量，以及如何通過燃燒食物來估算其熱量。 => 摘要：食物的養分和能量，以及通過燃燒食物來估算其熱量。 => 關鍵字：食物，養分，能量，燃燒，熱量\n第 2 段：介紹如何通過燃燒花生米來測量其熱量，並探討花生米中養分本身所含的熱量是否與燃燒後所產生的熱量相同。 => 摘要：通過燃燒花生米來測量其熱量，並探討養分本身所含的熱量是否與燃燒後所產生的熱量相同。 => 關鍵字：花生米，燃燒，熱量，養分，比較\n第 3 段：介紹一種市售鮮乳的營養標示，並問題是該鮮乳在人體內最多能夠產生多少熱量。 => 摘要：介紹市售鮮乳的營養標示，並問題是該鮮乳在人體內最多能夠產生多少熱量。 => 關鍵字：鮮乳，營養標示，熱量，人體，問題\n第 4 段：介紹測量食物中澱粉和糖的方法，包括使用碘液和本氏液。 => 摘要：介紹測量食物中澱粉和糖的方法，包括使用碘液和本氏液。 => 關鍵字：澱粉，糖，測量，碘液，本氏液\n第 5 段：介紹測量花生米熱量的步驟，包括將花生固定在橡皮塞上，點燃花生，觀察水溫變化等。 => 摘要：介紹測量花生米熱量的步驟，包括將花生固定在橡皮塞上，點燃花生，觀察水溫變化等。 => 關鍵字：花生米，熱量，測量，步驟，觀察'}}], 'usage': {'completion_tokens': 775, 'prompt_tokens': 1481, 'total_tokens': 2256}}
# ['第 1 段：介紹食物所含的養分和能量，以及如何通過燃燒食物來估算其熱量。 ', ' 摘要：食物的養分和能量，以及通過燃燒食物來估算其熱量。 ', ' 關鍵字：食物，養分，能量，燃燒，熱量']
# ['第 2 段：介紹如何通過燃燒花生米來測量其熱量，並探討花生米中養分本身所含的熱量是否與燃燒後所產生的熱量相同。 ', ' 摘要：通過燃燒花生米來測量其熱量，並探討養分本身所含的熱量是否與燃燒後所產生的熱量相同。 ', ' 關鍵字：花生米，燃燒，熱量，養分，比較']
# ['第 3 段：介紹一種市售鮮乳的營養標示，並問題是該鮮乳在人體內最多能夠產生多少熱量。 ', ' 摘要：介紹市售鮮乳的營養標示，並問題是該鮮乳在人體內最多能夠產生多少熱量。 ', ' 關鍵字：鮮乳，營養標示，熱量，人體，問題']
# ['第 4 段：介紹測量食物中澱粉和糖的方法，包括使用碘液和本氏液。 ', ' 摘要：介紹測量食物中澱粉和糖的方法，包括使用碘液和本氏液。 ', ' 關鍵字：澱粉，糖，測量，碘液，本氏液']
# ['第 5 段：介紹測量花生米熱量的步驟，包括將花生固定在橡皮塞上，點燃花生，觀察水溫變化等。 ', ' 摘要：介紹測量花生米熱量的步驟，包括將花生固定在橡皮塞上，點燃花生，觀察水溫變化等。 ', ' 關鍵字：花生米，熱量，測量，步驟，觀察']
